-- %%
select * from formula_one.gold.v_driver_standing 
where driver_name in ('Max Verstappen','Lewis Hamilton')
and season > 2014
order by season;
-- Out:
-- Databricks visualization. Run in Databricks to view.
