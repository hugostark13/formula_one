# %%
raw_path = "/Volumes/workspace/f1/raw"
processed_path = "/Volumes/workspace/f1/processed"
presentation_path = "/Volumes/workspace/f1/presentation"

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.sql.window import Window
