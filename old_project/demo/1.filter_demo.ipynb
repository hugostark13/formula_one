# %%
# %run "../includes/configuration"

# %%
races_df = spark.read.parquet(f"{processed_path}/races")

# %%
races_filtered_df = races_df.filter("race_year = 2019 and round <= 5").display()

# %%
races_filtered_df = races_df.filter((races_df["race_year"] == 2019) & (races_df["round"] <= 5)).display()
