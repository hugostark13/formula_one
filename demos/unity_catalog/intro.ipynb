# %% [markdown]
# ### Check whether the workspace is attached to a Unity Catalog Metastore

# %%
# %sql
SELECT current_metastore();

# %% [markdown]
# ### Configure Access to Cloud Storage via Unity Catalog

# %% [markdown]
# ### Access Cloud Storage

# %%
# %fs ls 'abfss://demo@databrickscourse.dfs.core.windows.net/'

# %% [markdown]
# ### Create External Location

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS databricks_course_ext_demo
URL 'abfss://demo@databrickscourse.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `databricks-course`)
COMMENT 'External location for the demo container';
