# %%
# Unity Catalog Object Names
catalog_name = 'formula_one'
bronze_schema = 'bronze'
silver_schema = 'silver'
gold_schema = 'gold'
control_schema = 'control'

# %%
landing_folder_path = '/Volumes/formula_one/landing/files'
